# %% [raw]
# Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you
# predict them at all?
#
# Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is
# one? Why are the latter considered “good enough”?
#
# Q3. What are the two main factors that influence the behaviour of normal probability distribution?
#
# Q4. Provide a real-life example of a normal distribution.
#
# Q5. In the short term, how can you expect a probability distribution to behave? What do you think will
# happen as the number of trials grows?
#
# Q6. What kind of object can be shuffled by using random.shuffle?
#
# Q7. Describe the math package general categories of functions.
#
# Q8. What is the relationship between exponentiation and logarithms?
#
# Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# ## Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?
# Sol:
#
#     A probability distribution is a statistical function that describes all the possible values and likelihoods that a random variable can take within a given range.

# %% [markdown]
# ## Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one?
#
# Sol:
#     ![slide_2.jpeg](attachment:slide_2.jpeg)

# %% [markdown]
# ## Q3. What are the two main factors that influence the behaviour of normal probability distribution?
#
# Sol:
#     Normal distributions are symmetric, unimodal, and asymptotic, and the mean, median, and mode are all equal. A normal distribution is perfectly symmetrical around its center. That is, the right side of the center is a mirror image of the left side.

# %% [markdown]
# ## Q4. Provide a real-life example of a normal distribution.
# Sol :A fair rolling of dice is also a good example of normal distribution.

# %% [markdown]
# ## Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?

# %% [markdown]
# ## Q6. What kind of object can be shuffled by using random.shuffle?
#
# Sol :
#        To randomly shuffle elements of lists ( list ), strings ( str ) and tuples ( tuple ) in Python, use the random module. random provides shuffle() that shuffles the original list in place, and sample() that returns a new list that is randomly shuffled. sample() can also be used for strings and tuples

# %% [markdown]
# ## Q7. Describe the math package general categories of functions.
# Sol:
#     ''
#
# Functions are classified by the type of mathematical equation which represents their relationship. Some functions are algebraic. Other functions like f(x) = sin x, deal with angles and are known as trigonometric. Still other functions have logarithmic and exponential relationships and are classified as such.

# %% [markdown]
# ## Q8. What is the relationship between exponentiation and logarithms?
# Sol :
#     Logarithmic functions are the inverses of exponential functions. The inverse of the exponential function y = ax is x = ay. The logarithmic function y = logax is defined to be equivalent to the exponential equation x = ay.

# %% [markdown]
# ## Q9. What are the three logarithmic functions that Python supports?
# Sol ; log2(x) log(x, Base) log10(x)
